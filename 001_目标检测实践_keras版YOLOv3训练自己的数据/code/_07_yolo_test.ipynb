# %%
from _06_yolo import YoloModel
yolo_model = YoloModel(weightsFilePath='saved_model/trained_weights.h5')
# Out:
# /home/leikun/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
with open('dataset_test.txt') as file:
    line_list = file.readlines()
jpgFilePath_list = [k.split()[0] for k in line_list]
jpgFilePath_list
# Out:
# ['../resources/images_416x416/092.jpg',
#  '../resources/images_416x416/133.jpg',
#  '../resources/images_416x416/129.jpg',
#  '../resources/images_416x416/064.jpg',
#  '../resources/images_416x416/029.jpg',
#  '../resources/images_416x416/187.jpg',
#  '../resources/images_416x416/055.jpg',
#  '../resources/images_416x416/051.jpg',
#  '../resources/images_416x416/069.jpg',
#  '../resources/images_416x416/049.jpg',
#  '../resources/images_416x416/033.jpg',
#  '../resources/images_416x416/003.jpg',
#  '../resources/images_416x416/147.jpg',
#  '../resources/images_416x416/042.jpg',
#  '../resources/images_416x416/004.jpg',
#  '../resources/images_416x416/083.jpg',
#  '../resources/images_416x416/178.jpg',
#  '../resources/images_416x416/191.jpg',
#  '../resources/images_416x416/127.jpg',
#  '../resources/images_416x416/116.jpg']

# %%
from PIL import Image
jpgFilePath = jpgFilePath_list[0]
image = Image.open(jpgFilePath)
yolo_model.detect_image(image)
# Out:
# 检测这张图片用时2.74秒
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=416x416 at 0x7F31CF275208>
